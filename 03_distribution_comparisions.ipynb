# %% [markdown]
# # Comparing the t-Distribution and Normal Distribution

# %%
import numpy as np
import statistics as st
import matplotlib.pyplot as plt
import scipy.stats as sc
from scipy.stats import t

# %%
# Effect of degrees of freedom on t-Distribution shape
# After degrees of freedom (df) is greater than 30 then curves are very similar
fig, ax = plt.subplots()
plt.xlim(-4,4)
for i in range(3,34,10):
    x = t.rvs(df=i, size=10000)
    sns.kdeplot(x, ax=ax, label=f"t-Distribution (df = {i})")
plt.legend()

# %%
from datetime import datetime
import random
fig.savefig(f'./images/t_distribution_{datetime.today().strftime("%Y_%m_%d")}_{random.randint(10, 99)}')

# %% [markdown]
# Note: The degrees of freedom don't really change the curve very much unless using small numbers
#
# As DF increases, the distribution approaches a normal distribution
#
# After 30 DF the t-critical value and z-critical value are basically the same

# %%
# Normal versus T-Distribution
fig, ax = plt.subplots()
plt.xlim(-4,4)

x = t.rvs(df=30, size=10000)
sns.kdeplot(x, ax=ax, label="t-Distribution")

mean = 0
std = 1
x=np.linspace(mean-3*std, mean+3*std,1000)
iq=sc.norm(mean,std)
ax.plot(x,iq.pdf(x),'b', label="Normal Distribution")
plt.legend()

# %%
from datetime import datetime
import random
fig.savefig(f'./images/t_normal_compare_{datetime.today().strftime("%Y_%m_%d")}_{random.randint(10, 99)}')

# %% [markdown]
# Shows t-dist has heavy tails (aka greater kurtosis) thus causing a smaller peak

# %% [markdown]
# As degrees of freedom are over 30 then the t-distribution becomes similar to the normal distribution
