# %%
# Dependencies
import pandas as pd
import numpy as np
import statsmodels.api as sm

# %%
# Generate sample data
np.random.seed(42)
num_samples = 1000

# Latent variables (unobserved)
latent1 = np.random.normal(0, 1, num_samples)
latent2 = np.random.normal(0, 1, num_samples)
latent3 = np.random.normal(0, 1, num_samples)

# Observed variables (indicators)
observed1 = 0.5 * latent1 + np.random.normal(0, 0.5, num_samples)
observed2 = 0.7 * latent1 + np.random.normal(0, 0.7, num_samples)

observed3 = 0.3 * latent2 + np.random.normal(0, 0.3, num_samples)
observed4 = 0.6 * latent2 + np.random.normal(0, 0.6, num_samples)

observed5 = 0.4 * latent3 + np.random.normal(0, 0.4, num_samples)
observed6 = 0.8 * latent3 + np.random.normal(0, 0.8, num_samples)

# Create a DataFrame
data = pd.DataFrame({
    'Observed1': observed1,
    'Observed2': observed2,
    'Observed3': observed3,
    'Observed4': observed4,
    'Observed5': observed5,
    'Observed6': observed6,
})

# %%
# Build the SEM model
model = sm.OLS(endog=data[['Observed1', 'Observed2', 'Observed3', 'Observed4', 'Observed5', 'Observed6']],
               exog=sm.add_constant(data[['Observed1', 'Observed3', 'Observed5']]))  # Define the structural paths here
result = model.fit()

# %%
# Print the model summary
print(result)
# Out:
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x000001B870DC7F10>

# %% [markdown]
# ### Example 2

# %%
# pip install semopy

# %%
import pandas as pd
import numpy as np
import semopy

# %%
# Generate sample data
np.random.seed(42)
num_samples = 1000

# Latent variables (unobserved)
latent1 = np.random.normal(0, 1, num_samples)
latent2 = np.random.normal(0, 1, num_samples)
latent3 = np.random.normal(0, 1, num_samples)

# Observed variables (indicators)
observed1 = 0.5 * latent1 + np.random.normal(0, 0.5, num_samples)
observed2 = 0.7 * latent1 + np.random.normal(0, 0.7, num_samples)

observed3 = 0.3 * latent2 + np.random.normal(0, 0.3, num_samples)
observed4 = 0.6 * latent2 + np.random.normal(0, 0.6, num_samples)

observed5 = 0.4 * latent3 + np.random.normal(0, 0.4, num_samples)
observed6 = 0.8 * latent3 + np.random.normal(0, 0.8, num_samples)

# Create a DataFrame
data = pd.DataFrame({
    'Observed1': observed1,
    'Observed2': observed2,
    'Observed3': observed3,
    'Observed4': observed4,
    'Observed5': observed5,
    'Observed6': observed6,
})

# %%
# Build the SEM model
model_spec = '''
    Latent1 =~ Observed1 + Observed2 + Observed3 + Observed4 + Observed5 + Observed6
    Latent2 =~ Observed3 + Observed4
    Latent3 =~ Observed5 + Observed6
'''

model = semopy.Model(model_spec)
model.fit(data)

# Print the model summary
# print(model.summary())
# Out:
# SolverResult(fun=0.0027734972288557813, success=True, n_it=46, x=array([ 1.93643179e+00,  3.62816674e-01,  2.97151410e-01,  9.99684524e-01,
#        -8.91823543e-02, -1.54303338e-01,  9.74353051e-01,  2.03989552e-20,
#         2.89189042e-01,  5.47874117e-01,  9.77539293e-01,  3.27492937e-01,
#         9.58517847e-20,  2.14946761e-01, -5.17959098e-05, -7.22776360e-02,
#         3.19870004e-01,  3.36758548e-02,  1.68607028e-01]), message='Optimization terminated successfully', name_method='SLSQP', name_obj='MLW')

# %%
from semopy import Optimizer
opt2 = Optimizer(model)

obj_func_val = opt2.optimize()

# %%
from semopy.inspector import inspect
inspect(opt2)
# Out:
# WARNING:root:Fisher Information Matrix is not PD.Moore-Penrose inverse will be used instead of Cholesky decomposition. See 10.1109/TSP.2012.2208105.
#          lval  op       rval      Estimate  Std. Err   z-value   p-value
# 0   Observed1   ~    Latent1  1.000000e+00         -         -         -
# 1   Observed2   ~    Latent1  1.936437e+00  0.828016  2.338647  0.019354
# 2   Observed3   ~    Latent1  3.628071e-01   0.18072  2.007565   0.04469
# 3   Observed3   ~    Latent2  1.000000e+00         -         -         -
# 4   Observed4   ~    Latent1  2.971633e-01  0.213386  1.392608  0.163738
# 5   Observed4   ~    Latent2  9.996858e-01  0.909842  1.098746  0.271879
# 6   Observed5   ~    Latent1 -8.917426e-02  0.091362 -0.976055  0.329037
# 7   Observed5   ~    Latent3  1.000000e+00         -         -         -
# 8   Observed6   ~    Latent1 -1.543112e-01  0.115964 -1.330678  0.183295
# 9   Observed6   ~    Latent3  9.743502e-01  0.930875  1.046704  0.295236
# 10    Latent2  ~~    Latent2  2.149585e-01   0.19315  1.112908  0.265748
# 11    Latent2  ~~    Latent3 -1.354555e-05  0.013204 -0.001026  0.999181
# 12    Latent2  ~~    Latent1 -7.226169e-02  0.042396 -1.704444  0.088298
# 13    Latent3  ~~    Latent3  3.198734e-01  0.304441   1.05069  0.293401
# 14    Latent3  ~~    Latent1  3.369335e-02  0.022133  1.522318  0.127929
# 15    Latent1  ~~    Latent1  1.686685e-01  0.073733  2.287573  0.022162
# 16  Observed5  ~~  Observed5  1.982744e-20  0.298671       0.0       1.0
# 17  Observed2  ~~  Observed2  2.891873e-01  0.269633  1.072521  0.283486
# 18  Observed4  ~~  Observed4  5.478713e-01  0.168914  3.243493  0.001181
# 19  Observed6  ~~  Observed6  9.775368e-01  0.286852  3.407805  0.000655
# 20  Observed1  ~~  Observed1  3.274905e-01  0.073302  4.467708  0.000008
# 21  Observed3  ~~  Observed3  1.444535e-19  0.167186       0.0       1.0

# %%
from semopy import gather_statistics

stats = gather_statistics(opt2)
print (stats)
# Out:
# WARNING:root:Fisher Information Matrix is not PD.Moore-Penrose inverse will be used instead of Cholesky decomposition. See 10.1109/TSP.2012.2208105.
# SEMStatistics(dof=2, ml=0.0027733837961863017, fun=0.0027733837961863017, chi2=(2.7733837961863017, 0.24990063550852315), dof_baseline=15, chi2_baseline=838.4568319508445, rmsea=0.019674322785555316, cfi=0.999060808331198, gfi=0.9966922759878604, agfi=0.9751920699089527, nfi=0.9966922759878604, tli=0.9929560624839853, aic=37.99445323240763, bic=131.24180353306824, params=[ParametersStatistics(value=1.936436542629728, se=0.8280158217721154, zscore=2.3386467887570523, pvalue=0.01935372116962708), ParametersStatistics(value=0.3628070739621391, se=0.1807199640375913, zscore=2.007564996442034, pvalue=0.044689537328554074), ParametersStatistics(value=0.29716328761637895, se=0.21338623656281688, zscore=1.3926075664561761, pvalue=0.16373849369233628), ParametersStatistics(value=0.9996858386517502, se=0.9098424218581179, zscore=1.0987461285977977, pvalue=0.2718788159084691), ParametersStatistics(value=-0.08917425920316367, se=0.09136191080918461, zscore=-0.9760551023110051, pvalue=0.32903715890831586), ParametersStatistics(value=-0.15431122261854935, se=0.11596439250118826, zscore=-1.3306776268899738, pvalue=0.18329510777315106), ParametersStatistics(value=0.9743502391844158, se=0.9308748601066684, zscore=1.0467037847296885, pvalue=0.2952362176349692), ParametersStatistics(value=1.9827438356463473e-20, se=0.2986712953577027, zscore=6.638548352177875e-20, pvalue=1.0), ParametersStatistics(value=0.28918734173788285, se=0.2696333763087037, zscore=1.0725205673563174, pvalue=0.2834862810388461), ParametersStatistics(value=0.5478712999069633, se=0.1689139506320512, zscore=3.243493493898318, pvalue=0.0011807350725725474), ParametersStatistics(value=0.9775367866940933, se=0.28685234345710614, zscore=3.407804778268648, pvalue=0.0006548772898309352), ParametersStatistics(value=0.32749053454358135, se=0.0733016812428561, zscore=4.467708366116507, pvalue=7.906198851381774e-06), ParametersStatistics(value=1.4445347069568408e-19, se=0.16718612539687408, zscore=8.640278632686163e-19, pvalue=1.0), ParametersStatistics(value=0.21495853390363945, se=0.19315024108009335, zscore=1.1129084421561244, pvalue=0.2657477539225317), ParametersStatistics(value=-1.3545551800640906e-05, se=0.013203792228258782, zscore=-0.00102588344056375, pvalue=0.9991814635851672), ParametersStatistics(value=-0.07226169442304532, se=0.04239603913023881, zscore=-1.7044444694315914, pvalue=0.08829808204252587), ParametersStatistics(value=0.3198733947809704, se=0.3044412599733696, zscore=1.050690024104814, pvalue=0.29340097923978714), ParametersStatistics(value=0.03369334595288884, se=0.022132919312081223, zscore=1.522318202866942, pvalue=0.1279293692125658), ParametersStatistics(value=0.16866847512750907, se=0.07373251520138382, zscore=2.2875725134907086, pvalue=0.022162428107644683)])
